# %% [markdown]
# Exercise 1 (Answer)

# %%
name = input("Enter your name: ")
print("Welcome", name)
# Out:
# Enter your name: gab
# Welcome gab

# %% [markdown]
# Exercise 2 (Answer)

# %%
hours = input("Enter Hours: ")
rate = input("Enter Rate: ")
pay = float (hours) * float (rate)
print("Pay: ",pay)
# Out:
# Enter Hours: 5
# Enter Rate: 5
# Pay:  25.0

# %% [markdown]
# Exercise 3 (Answer)

# %%
width = 2
_width = 2.0
height = 3
area = (int (width) + float (_width)) * int (height)

print("Area:" ,area)
# Out:
# Area: 12.0

# %% [markdown]
# Exercise 4 (Answer)

# %%
number = input("Enter a number: ")
answer = int(number)**2
print("The square of", number, "is", answer)
# Out:
# Enter a number: 2
# The square of 2 is 4

# %% [markdown]
# Challenge (Answer)

# %%
cel = input("Enter Celsius Temperature: ")
conv = (float(cel)*1.8)+32
print(cel, "Degrees Celsius is", conv, "Degrees Fahrenheit")
# Out:
# Enter Celsius Temperature: 32
# 32 Degrees Celsius is 89.6 Degrees Fahrenheit
